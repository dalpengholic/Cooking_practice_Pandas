# %% [markdown]
# # Pandas basic cooking recipe

# %% [markdown]
# `Pandas` is basically do the same as a spreadsheet program like Microsoft Excel. I like Pandas because it is powerful but also a bit confusing to use methods when I need them or need to mix some of methods. So it is worth to learn basic methods to save time and energy.
#
# Let's get started! :)

# %% [markdown]
# ## 0. Import pandas

# %% [markdown]
# To use pandas, we need to import.

# %%
import pandas as pd

# %% [markdown]
# After import, we can access methods and attributes in pandas by starting with `pd.`. For example, `pd.read_csv`, `pd.drop()` and so on.

# %% [markdown]
# ## 1. Read data

# %% [markdown]
# If you have any csv files, you can read them using `pd.read_csv` method.

# %%
df_1 = pd.read_csv("../data/311-service-requests.csv")
# Out:
# /Users/dalpengholic/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# There are some arguments to use to read a csv. For instance.. `sep`, `encoding`, `index_col`

# %%
df_2 = pd.read_csv("../data/bikes.csv", sep=";", encoding='latin1', index_col='Date')

# %% [markdown]
# I will keep updating this section.

# %% [markdown]
# ## 2. Brief checking of a dataframe

# %% [markdown]
# When you read a csv, you might want to see how it looks like. Here, some good methods to be used. When you make a dataframe instance, you can use methods and attributes using `dataframe name.` like `df_1.head()`, `df_1["column name"]`

# %%
# Use comment and uncomment to execute each line
df_1.head() # This shows top rows. Default rows are 5.
df_1.head(n=3) # This shows top 3 rows
df_1.tail() # This shows bottom 5 rows
df_1.tail(n=4) # This shows bottom 4 rows
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 111066    26428987  10/04/2013 12:00:45 AM  10/04/2013 01:25:01 AM   NYPD
# 111067    26426115  10/04/2013 12:00:28 AM  10/04/2013 04:17:32 AM   NYPD
# 111068    26428033  10/04/2013 12:00:10 AM  10/04/2013 01:20:52 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 111066  New York City Police Department  Noise - Street/Sidewalk
# 111067  New York City Police Department       Noise - Commercial
# 111068  New York City Police Department         Blocked Driveway
#
#             Descriptor        Location Type Incident Zip  \
# 111066    Loud Talking      Street/Sidewalk        10016
# 111067    Loud Talking  Club/Bar/Restaurant        11226
# 111068  Partial Access      Street/Sidewalk        11236
#
#             Incident Address                    ...                     \
# 111066    344 EAST 28 STREET                    ...
# ...

# %% [markdown]
# Many columns are omitted. If you want to see them, use `pd.set_option('display.max_columns', None)`

# %%
pd.set_option('display.max_columns', None)
df_1.head(n=3)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department          Illegal Parking
# 2  New York City Police Department       Noise - Commercial
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
#
#    Incident Address Street Name   Cross Street 1   Cross Street 2  \
# 0  90-03 169 STREET  169 STREET        90 AVENUE        91 AVENUE
# ...

# %% [markdown]
# If you want to check how a dataframe is big, use `df.shape`. It returns a set with data of (#rows, #columns).

# %%
# Use comment and uncomment to execute each line
df_1.shape # This shows the size of df_1
df_2.shape # This shows the size of df_2
# Out:
# (111069, 52)

# %% [markdown]
# If you want to se  general statistical information, use `df.describe()`. It return a dataframe of count, mean, std and quantile values from numerical columns.

# %%
print(df_1.shape)
df_1.describe()
# Out:
# (111069, 52)
#          Unique Key  X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# count  1.110690e+05                9.814300e+04                98143.000000
# mean   2.651565e+07                1.004544e+06               205553.153287
# std    4.694558e+04                2.206087e+04                31334.677543
# min    2.642588e+07                9.134950e+05               121152.000000
# 25%    2.647433e+07                9.920490e+05               182506.000000
# 50%    2.651472e+07                1.003205e+06               203251.000000
# 75%    2.655684e+07                1.016823e+06               233366.000000
# max    2.659613e+07                1.067024e+06               271485.000000
#
#        School or Citywide Complaint      Latitude     Longitude
# count                           0.0  98143.000000  98143.000000
# mean                            NaN     40.730821    -73.926738
# std                             NaN      0.086006      0.079563
# ...

# %% [markdown]
# If you use info() method, you can easily see how many rows are in the dataframe, the type of a each row, columns name, how many non-null data in a column.

# %%
# Use comment and uncomment to execute each line
df_1.info()
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 310 entries, 01/01/2012 to 05/11/2012
# Data columns (total 9 columns):
# Berri 1                                310 non-null int64
# Brébeuf (données non disponibles)      0 non-null float64
# Côte-Sainte-Catherine                  310 non-null int64
# Maisonneuve 1                          310 non-null int64
# Maisonneuve 2                          310 non-null int64
# du Parc                                310 non-null int64
# Pierre-Dupuy                           310 non-null int64
# Rachel1                                310 non-null int64
# St-Urbain (données non disponibles)    0 non-null float64
# dtypes: float64(2), int64(7)
# memory usage: 24.2+ KB

# %% [markdown]
# There is time when you need to check the names of the columns or the indices in a dataframe. Use `df.columns` and `df.index`

# %%
# Use comment and uncomment to execute each line
df_1.columns
df_2.index
# Out:
# Index(['01/01/2012', '02/01/2012', '03/01/2012', '04/01/2012', '05/01/2012',
#        '06/01/2012', '07/01/2012', '08/01/2012', '09/01/2012', '10/01/2012',
#        ...
#        '27/10/2012', '28/10/2012', '29/10/2012', '30/10/2012', '31/10/2012',
#        '01/11/2012', '02/11/2012', '03/11/2012', '04/11/2012', '05/11/2012'],
#       dtype='object', name='Date', length=310)

# %% [markdown]
# It happens frequently you want to access a column or several columns to just see or modify them. There are 2 ways to do it. One is `df.column name`. The other is `df['column name']`. The first one is not able to be used when a column name has a empty space.

# %%
# Use comment and uncomment to execute each line
# I used head() here to just to see some of rows.
print(df_1.columns[0:3])
df_1['Unique Key'].head()
df_1['Closed Date'].head()
df_1[['Closed Date','Unique Key']].head()
print(df_2.columns)
df_2.Rachel1.head()
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date'], dtype='object')
#               Closed Date  Unique Key
# 0                     NaN    26589651
# 1                     NaN    26593698
# 2  10/31/2013 02:40:32 AM    26594139
# 3  10/31/2013 02:21:48 AM    26595721
# 4                     NaN    26590930

# %% [markdown]
# ## 3. Summary of Ch.1

# %% [markdown]
# We have practiced..
# - `pd.read_csv`
# - `df.head()`, `df.tail(n=3)`
# -  `pd.set_option('display.max_columns', None)`
# -  `df.shape`, `df.describe()`,`df.info()`
# - `df.columns`, `df.index`
# - `df.column1` or `df[['col1','col2']]`
